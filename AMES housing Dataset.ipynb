# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
pd.set_option('display.max_columns',500)

# %%
df = pd.read_csv(r"F:\Full Stack Data Science I Neuron\kaggle datasets\AMES housing dataset\archive\AmesHousing.csv")

# %%
df.drop(labels = "Order",axis = 1,inplace = True)

# %%
df.head(2)
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  SalePrice
# 0        0       5    2010        WD           Normal     215000
# 1        0       6    2010        WD           Normal     105000
#
# [2 rows x 81 columns]

# %% [markdown]
# # Getting infromation of the dataset

# %%
df.shape
# Out:
# (2930, 81)

# %%
df.columns
# Out:
# Index(['PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street',
#        'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config',
#        'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Overall Qual', 'Overall Cond', 'Year Built',
#        'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2',
#        'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air',
#        'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual',
#        'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Fireplace Qu',
# ...

# %%
df.describe()
# Out:
#                 PID  MS SubClass  Lot Frontage       Lot Area  Overall Qual  \
# count  2.930000e+03  2930.000000   2440.000000    2930.000000   2930.000000
# mean   7.144645e+08    57.387372     69.224590   10147.921843      6.094881
# std    1.887308e+08    42.638025     23.365335    7880.017759      1.411026
# min    5.263011e+08    20.000000     21.000000    1300.000000      1.000000
# 25%    5.284770e+08    20.000000     58.000000    7440.250000      5.000000
# 50%    5.354536e+08    50.000000     68.000000    9436.500000      6.000000
# 75%    9.071811e+08    70.000000     80.000000   11555.250000      7.000000
# max    1.007100e+09   190.000000    313.000000  215245.000000     10.000000
#
#        Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  \
# count   2930.000000  2930.000000     2930.000000   2907.000000   2929.000000
# mean       5.563140  1971.356314     1984.266553    101.896801    442.629566
# ...

# %% [markdown]
# # Checking the datatypes

# %%
df.dtypes
# Out:
# PID                 int64
# MS SubClass         int64
# MS Zoning          object
# Lot Frontage      float64
# Lot Area            int64
#                    ...
# Mo Sold             int64
# Yr Sold             int64
# Sale Type          object
# Sale Condition     object
# SalePrice           int64
# Length: 81, dtype: object

# %% [markdown]
# # Checking for null values

# %%
df.isnull().sum()
# Out:
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
# Lot Area            0
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 81, dtype: int64

# %%
df.isnull().sum().index
# Out:
# Index(['PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street',
#        'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config',
#        'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Overall Qual', 'Overall Cond', 'Year Built',
#        'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2',
#        'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air',
#        'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual',
#        'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Fireplace Qu',
# ...

# %% [markdown]
# # separating numerical and categorical variables

# %%
numeric_data = df.select_dtypes(include=[np.number])

# %%
categorical_data = df.select_dtypes(exclude=[np.number])

# %%
len(categorical_data.columns)+len(numeric_data.columns) # cross checking
# Out:
# 81

# %%
df.shape
# Out:
# (2930, 81)

# %% [markdown]
# # checking for null values in numerical and categorical data

# %%
l1=[]
for j in categorical_data:
    if categorical_data[j].isnull().sum()>1:
        l1.append(j)

# %%
l2=[]
for i in numeric_data:
    if numeric_data[i].isnull().sum()>1:
        l2.append(i)

# %%
len(l2)   # number of columns having null values in the numerical data
# Out:
# 5

# %%
len(l1)
# Out:
# 15

# %%
numeric_data.isnull().sum()>1        # checking the above claim
# Out:
# PID                False
# MS SubClass        False
# Lot Frontage        True
# Lot Area           False
# Overall Qual       False
# Overall Cond       False
# Year Built         False
# Year Remod/Add     False
# Mas Vnr Area        True
# BsmtFin SF 1       False
# BsmtFin SF 2       False
# Bsmt Unf SF        False
# Total Bsmt SF      False
# 1st Flr SF         False
# 2nd Flr SF         False
# Low Qual Fin SF    False
# Gr Liv Area        False
# Bsmt Full Bath      True
# Bsmt Half Bath      True
# Full Bath          False
# Half Bath          False
# Bedroom AbvGr      False
# Kitchen AbvGr      False
# TotRms AbvGrd      False
# Fireplaces         False
# Garage Yr Blt       True
# Garage Cars        False
# Garage Area        False
# Wood Deck SF       False
# Open Porch SF      False
# Enclosed Porch     False
# 3Ssn Porch         False
# Screen Porch       False
# Pool Area          False
# Misc Val           False
# Mo Sold            False
# Yr Sold            False
# ...

# %%
categorical_data.isnull().sum()>1
# Out:
# MS Zoning         False
# Street            False
# Alley              True
# Lot Shape         False
# Land Contour      False
# Utilities         False
# Lot Config        False
# Land Slope        False
# Neighborhood      False
# Condition 1       False
# Condition 2       False
# Bldg Type         False
# House Style       False
# Roof Style        False
# Roof Matl         False
# Exterior 1st      False
# Exterior 2nd      False
# Mas Vnr Type       True
# Exter Qual        False
# Exter Cond        False
# Foundation        False
# Bsmt Qual          True
# Bsmt Cond          True
# Bsmt Exposure      True
# BsmtFin Type 1     True
# BsmtFin Type 2     True
# Heating           False
# Heating QC        False
# Central Air       False
# Electrical        False
# Kitchen Qual      False
# Functional        False
# Fireplace Qu       True
# Garage Type        True
# Garage Finish      True
# Garage Qual        True
# Garage Cond        True
# Paved Drive       False
# ...

# %% [markdown]
# # Information about dataset (to decide the further set of analysis)
# Ames housing data
# A team of researchers collects data from the sale of individual residential properties in Ames, Iowa. The researchers want to identify the variables that affect the sale price. Variables include the lot size and various features of the residential property.
#
# You can use this data to demonstrate Random Forests® Regression.
#
# The second data set includes a small number of new data points for the same variables. You can use this data set to demonstrate Predict for Random Forests® Regression.
#
#
# 1. Sale Price	The sale price of the property
#
# 2. Lot Frontage	The amount of linear feet of street connected to property
#
# 3. Lot Area	The lot size in square feet
# 4. Veneer Area	The amount of masonry veneer area in square feet
# 5. Basement SF 1	The amount of type 1 finished basement area in square feet
# 6. Basement SF 2	The amount of type 2 finished basement area in square feet
# 7. Basement Unf SF	The amount of unfinished basement area in square feet
# 8. Total Basement SF	The total amount of basement area in square feet
# 9. 1st Floor SF	The amount of area on the first floor in square feet
# 10. 2nd Floor SF	The amount of area on the second floor in square feet
# 11. Low Quality SF	The amount of low quality finished are in square feet (all floors)
# 12. Living Area SF	The amount of above grade living area in square feet
# 13. Garage Area SF	The size of the garage in square feet
# 14. Wood Deck SF	The wood deck area in square feet
# 15. Open Porch SF	The open porch area in square feet
# 16. Enclosed Porch	The enclosed porch area in square feet
# 17. Season Porch	The three-season porch area in square feet
# 17. Screen Porch	The screened porch area in square feet
# 18. Pool Area	The pool area in square feet
# 19. Misc Value	The monetary value of miscellaneous feature in dollars
# 20. Year Built	The original construction date
# 21. Year Remod/Add	The remodel date; this date is the same as construction date if no remodeling or additions
# 22. Basement Full Bath	The number of full bathrooms in the basement
# 23. Basement Half Bath	The number of half bathrooms in the basement
# 24. Full Bath	The number of full bathrooms above grade
# 25. Half Bath	The number of half bathrooms above grade
# 26. Bedroom	The number of bedrooms above grade
# 27. Kitchen	The number of kitchens above grade
# Total Rooms	The total number of rooms above grade
#
#
# Fireplaces	The number of fireplaces
#
# Garage Year	The original construction date of the garage
#
# Garage Cars	The size of garage in car capacity
#
# Month Sold	The month the property was sold
#
# Year Sold	The year the property was sold
#
# Type	The type of property: 20, 30, 40, 45, 50, 60, 70, 75, 80, 85, 90, 120, 150, 160, 180, or 190
#
# Zoning	The type of zoning: 1, 2, 3, 4, 5, 6, or 7
#
# Street	The type of road access to property: Gravel or Paved
#
# Alley	The type of alley access to property: Gravel or Paved
#
# Lot Shape	The shape of the lot: 1, 2, 3, or 4
#
# Land Contour	The flatness of the property: Level, Bank, Hill, or Low
#
# Utilities	The type of utilities available with the property: 1, 2, 3, or 4
#
# Configuration	The configuration of the property: Inside, Corner, Cul-de-sac, Two sides, or Three sides
#
# Slope	The slope of the lot: 1, 2, or 3
#
# Neighborhood	The neighborhood of the property: Blmngtn, Blueste, BrDale, BrkSide, ClearCr, CollgCr, Crawfor, Edwards,
# Gilbert, Greens, GrnHill, IDOTRR, Landmrk, MeadowV, Mitchel, NAmes, NoRidge, NPkVill, NridgHt, NWAmes, OldTown, Sawyer,
# SawyerW, Somerst, StoneBr, SWISU, Timber, or Veenker
#
#
# Condition 1	Proximity to various type 1 conditions: Artery, Feeder, Normal, Positive A, Positive N, Adjacent EW, Adjacent NS,
# Near EW, or Near NS
#
# Condition 2	Proximity to various type 2 conditions: Artery, Feeder, Normal, Positive A, Positive N, Adjacent EW, Adjacent NS, Near EW, or Near NS
#
# Quality	The overall material and finish quality of the property: 1–10
#
# Condition	The overall condition of the property: 1–10
#
# Roof Style	The roof style of the property: Flat, Gable, Gambrel, Hip, Mansard, or Shed
#
# Roof Material	The roof material: Tile, Composite, Membrane, Metal, Roll, Gravel, Shakes, or Wood
#
# Exterior 1st	The primary type of exterior covering on the house: Asbestos, Asphalt, Brick, Brick Face, Cinder, Cement,
# Board, Imitation Stucco, Metal, Plywood, PreCast, Stone, Stucco, Vinyl, Wood Siding, or Wood Shingle.
#
# Exterior 2nd	The secondary type of exterior covering on the house: Asbestos, Asphalt, Brick, Brick Face, Cinder, Cement,
# Board, Imitation Stucco, Metal, Plywood, PreCast, Stone, Stucco, Vinyl, Wood Siding, or Wood Shingle.
#
# Veneer Type	The type of veneer on the house: Brick, Brick Face, Cinder, None, or Stone.
#
# Exterior Quality	The quality of the exterior material: 1, 2, 3, or 4
#
# Exterior Condition	The condition of the exterior material: 1, 2, 3, 4, or 5
#
# Foundation	The type of foundation: Brick, Cinder, Concrete, Slab, Stone, or Wood
#
# Basement Height	The ceiling height rating of the basement: 1, 2, 3, 4, or 5
#
# Basement Condition	The general condition of the basement: 1, 2, 3, 4, or 5
#
# Basement Exposure	The type basement access: 1, 2, 3, or 4
#
# Basement Finish Type 1	The rating of basement finished area, type 1: 1, 2, 3, 4, 5, or 6
#
# Basement Finish Type 2	The rating of basement finished area, type 2: 1, 2, 3, 4, 5, or 6
#
# Heating	The type of heating availalbe: Floor, Air, Water, Gravity, Other, or Wall
#
# Heating Quality	The overall heating quality: 1, 2, 3, 4, or 5
#
# Central Air	Whether the house has central air conditioning: N or Y
#
# Electrical	The type of electrical system: 1, 2, 3, 4, or 5
#
# Kitchen Quality	The quality of the kitchen: 1, 2, 3, 4, or 5
#
# Function	The function of the home with respect to deductions: 1, 2, 3, 4, 5, or 6
#
# Fireplace Quality	The fireplace quality: 1, 2, 3, 4, or 5
#
# Garage Type	The type of garage: Multiple, Attached, Basement, Built In, Car Port, Detached, or NA
#
# Garage Finish	The type of interior garage finish: 1, 2, 3, or 4
#
# Garage Quality	The quality or the garage: 1, 2, 3, 4, or 5
#
# Garage Condition	The general condition of the garage: 1, 2, 3, 4, or 5
#
# Paved Drive	Whether the driveway is paved: 1, 2, or 3
#
# Pool Quality	The quality of the pool: 1, 2, 3, 4, or 5
#
# Fence	The quality of the fence: 1, 2, 3, 4, or 5
#
# Misc Feature	Whether the property has the following miscellaneous features: Elevator, Second Garage, Shed, Tennis, Other, or
# None
#
# Sale Type	The type of sale: Conventional, Cash, VA, New, Court, Contract, Low Both, Low Interest, Low Payment, or Other
#
# Sale Condition	The condition of the sale: Normal, Abnormal, Adjoining, Allocation, Family, or Partial
#
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
# 20    1-STORY 1946 & NEWER ALL STYLES
#
# 30    1-STORY 1945 & OLDER
#
# 40    1-STORY W/FINISHED ATTIC ALL AGES
#
# 45    1-1/2 STORY - UNFINISHED ALL AGES
#
# 50    1-1/2 STORY FINISHED ALL AGES
#
# 60    2-STORY 1946 & NEWER
#
# 70    2-STORY 1945 & OLDER
#
# 75    2-1/2 STORY ALL AGES
#
# 80    SPLIT OR MULTI-LEVEL
#
# 85    SPLIT FOYER
#
# 90    DUPLEX - ALL STYLES AND AGES

# %% [markdown]
# # Analysis using correlation among variables

# %%
df.head(2)
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  SalePrice
# 0        0       5    2010        WD           Normal     215000
# 1        0       6    2010        WD           Normal     105000
#
# [2 rows x 81 columns]

# %% [markdown]
# # Relation among numeric data v/s Sale Price

# %%
numeric_data.head(2)
# Out:
#          PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 0  526301100           20         141.0     31770             6             5
# 1  526350040           20          80.0     11622             5             6
#
#    Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  ...  Wood Deck SF  \
# 0        1960            1960         112.0         639.0  ...           210
# 1        1961            1961           0.0         468.0  ...           140
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area  \
# 0             62               0           0             0          0
# 1              0               0           0           120          0
#
#    Misc Val  Mo Sold  Yr Sold  SalePrice
# 0         0        5     2010     215000
# 1         0        6     2010     105000
#
# [2 rows x 38 columns]

# %%
numeric_data.drop(labels="PID",axis = 1,inplace =True)

# %%
numeric_data.head(2)
# Out:
#    MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 0           20         141.0     31770             6             5
# 1           20          80.0     11622             5             6
#
#    Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  ...  \
# 0        1960            1960         112.0         639.0           0.0  ...
# 1        1961            1961           0.0         468.0         144.0  ...
#
#    Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# 0           210             62               0           0             0
# 1           140              0               0           0           120
#
#    Pool Area  Misc Val  Mo Sold  Yr Sold  SalePrice
# 0          0         0        5     2010     215000
# 1          0         0        6     2010     105000
#
# [2 rows x 37 columns]

# %%
numeric_list = numeric_data.columns

# %%
numeric_list
# Out:
# Index(['MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Mas Vnr Area',
#        'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area',
#        'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath', 'Half Bath',
#        'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd', 'Fireplaces',
#        'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'Wood Deck SF',
#        'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch',
#        'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold', 'SalePrice'],
#       dtype='object')

# %%
df["SalePrice"].max()
# Out:
# 755000

# %%
fig = plt.figure(figsize=(10, 30))
for i in range(0, len(numeric_list)):
    ax = plt.subplot(15, 3, i+1)

    sns.scatterplot(data= numeric_data ,x='SalePrice', y=numeric_list[i], color='b')
    plt.xlim(df["SalePrice"].min(),df["SalePrice"].max()) 
    plt.tight_layout()

# %% [markdown]
# # Observations
# 1. Sale Price for MS subclass upto 80 is higher +> upto two stroy building cost higher than split bulidings
# 2. Higher the Quality numeber, higher is the sale price
# 3. Higher the Quality numeber, higher is the sale price but better condition doesnt fetch significantly high price
# 4. Newer property fetch high Sale Price and that also is true for latest Remodelled property and Year of Garage Built
# 5. Higher the Masonary Veener area, higher is the price
# 6. Higher the finished basement SF!, higher the price, not much a difference with Basement SF2
# 7. Higher the total basement area,total elevation area,garage area, higher the Slae Price

# %% [markdown]
# # Finding outliers in the numerical data

# %%
numeric_data.head(2)
# Out:
#    MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 0           20         141.0     31770             6             5
# 1           20          80.0     11622             5             6
#
#    Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  ...  \
# 0        1960            1960         112.0         639.0           0.0  ...
# 1        1961            1961           0.0         468.0         144.0  ...
#
#    Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# 0           210             62               0           0             0
# 1           140              0               0           0           120
#
#    Pool Area  Misc Val  Mo Sold  Yr Sold  SalePrice
# 0          0         0        5     2010     215000
# 1          0         0        6     2010     105000
#
# [2 rows x 37 columns]

# %%
sns.boxplot(x=numeric_data["Lot Frontage"])    #testing box plot
# Out:
# <AxesSubplot:xlabel='Lot Frontage'>

# %%
for i in numeric_data:
    sns.boxplot(x=df[i])
    plt.show()

# %% [markdown]
# # Relation among Categorical data v/s Sale Price

# %%
categorical_data.columns
# Out:
# Index(['MS Zoning', 'Street', 'Alley', 'Lot Shape', 'Land Contour',
#        'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl',
#        'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Heating QC',
#        'Central Air', 'Electrical', 'Kitchen Qual', 'Functional',
#        'Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Pool QC', 'Fence', 'Misc Feature',
#        'Sale Type', 'Sale Condition'],
#       dtype='object')

# %%
sns.barplot(data=df, x=df["SalePrice"], y=categorical_data["MS Zoning"])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='MS Zoning'>

# %%
for j in categorical_data:
    plt.subplots(figsize=(10,7))
    sns.barplot(data=df, x=df["SalePrice"], y=categorical_data[j])
    plt.title("{} V/S SalePrice".format(j))
    plt.show();

# %% [markdown]
# # Continuous data type separated in numerical data type

# %%
continuous = numeric_data.select_dtypes("float")

# %%
cont.head()
# Out:
#    Lot Frontage  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  \
# 0         141.0         112.0         639.0           0.0        441.0
# 1          80.0           0.0         468.0         144.0        270.0
# 2          81.0         108.0         923.0           0.0        406.0
# 3          93.0           0.0        1065.0           0.0       1045.0
# 4          74.0           0.0         791.0           0.0        137.0
#
#    Total Bsmt SF  Bsmt Full Bath  Bsmt Half Bath  Garage Yr Blt  Garage Cars  \
# 0         1080.0             1.0             0.0         1960.0          2.0
# 1          882.0             0.0             0.0         1961.0          1.0
# 2         1329.0             0.0             0.0         1958.0          1.0
# 3         2110.0             1.0             0.0         1968.0          2.0
# 4          928.0             0.0             0.0         1997.0          2.0
#
#    Garage Area
# 0        528.0
# 1        730.0
# 2        312.0
# ...

# %% [markdown]
# # Discrete data type separated in numerical data type

# %%
numeric_data["Lot Frontage"].unique()
# Out:
# array([141.,  80.,  81.,  93.,  74.,  78.,  41.,  43.,  39.,  60.,  75.,
#         nan,  63.,  85.,  47., 152.,  88., 140., 105.,  65.,  70.,  26.,
#         21.,  53.,  24., 102.,  98.,  83.,  94.,  95.,  90.,  79., 100.,
#         44., 110.,  61.,  36.,  67., 108.,  59.,  92.,  58.,  56.,  73.,
#         72.,  84.,  76.,  50.,  55.,  68., 107.,  25.,  30.,  57.,  40.,
#         77., 120., 137.,  87., 119.,  64.,  96.,  71.,  69.,  52.,  51.,
#         54.,  86., 124.,  82.,  38.,  48.,  89.,  66.,  45.,  35., 129.,
#         31.,  42.,  28.,  99., 104.,  97., 103.,  34., 117., 149., 122.,
#         62., 174., 106., 112.,  32., 115., 128.,  91.,  33., 121., 144.,
#        130., 109., 150., 113., 125., 101.,  46., 114., 135., 136.,  37.,
#         22., 313.,  49., 123., 160., 195., 118., 134., 182., 116., 138.,
#        155., 126., 200., 168., 111., 131., 153., 133.])

# %%
len(numeric_data["Lot Frontage"].unique())
# Out:
# 129

# %%
discrete_data = [feature for feature in numeric_data if len(numeric_data[feature].unique())<25]

# %%
continuous_data = [feature for feature in numeric_data if len(numeric_data[feature].unique())>=25]

# %%
for feature in discrete_data:
    plt.figure(figsize=(10, 2))
    sns.histplot(data=df, x=df[feature],bins = 30,weights="Yr Sold")
    sns.set(rc={'figure.figsize':(5,5)})
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# # Overall observation for Discrete data
# 1. Maximum MS Subclass is 25 which may have outliers
# 2. Overall quality distribution is giving information that the quality of houses in the dataset have quality =5 which depics medium quality having maximum values.The data is left skewed mwaning the qualoty of houses is above average in the dataset
# 3. Condition of the house is average to good.
# 4. Majority of the houses are having 2 Full baths and atleast 1 full bath
# 5. The houses in the dataset have majorly 3 bedrooms
# 6. Majority of the houses have kitchen above the ground floor
# 7. Majority of the house owners have 2 cars
# 8. Maximum sales happen in the month of June. The data is normally distributed giving idea about the sales happening in Q1 of the Financial Year

# %%
for feature in continuous_data:
    plt.figure(figsize=(10, 2))
    sns.histplot(data=df, x=df[feature],bins = 50,weights="Yr Sold")
    sns.set(rc={'figure.figsize':(5,5)})
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# # Overall Observations for Continuous Data
# 1. Lot Frontage data is right skewed
# 2. Built Year are around distributed bimodally such that quite a lot of houses are built after 2000 near 1960
# 3. The Remodelling of the houses data is left skewed with majority of the remodelling is after 2000
# 4. Mas Vnr area is having outliers at 0 value
# 5. BsmtFin SF 1 data is right skewed with outliers having values at 0
# 6. Basement Unfurnished data os right skewed with majority values between 0 and 500
# 7. 1st Floor SF is normally distributed with maximum values around 1000 sq ft
# 8. Ground Floor Living Area is normally distributed with maximum values around 1500 sq ft
# 9. Garage area is a right skewed data with outlier around 0 value
# 10. Sale Prove is normally distributed  with slight right skew

# %% [markdown]
# # Further Miscellaneous analysis

# %%
df['Yr Sold'].unique()
# Out:
# array([2010, 2009, 2008, 2007, 2006], dtype=int64)

# %%
sns.barplot(x = df['Yr Sold'],y = df["SalePrice"],hue =df["Year Built"] )

# %%
plt.figure(figsize=(25, 10))
sns.histplot(data=df, x="Year Built",bins = 30,weights="Yr Sold")
sns.set(rc={'figure.figsize':(5,5)})
plt.xticks(rotation=90)
plt.show()

# %%
sns.jointplot(x = df["Year Built"], y = df["SalePrice"], kind = 'scatter')
# sns.jointplot(x = df["Year Built"], y = df["SalePrice"], kind = 'hex')

# %%
for i in cont:
    sns.jointplot(x = cont[i], y = df["SalePrice"], kind = 'scatter')
    plt.show()

# %% [markdown]
# # Joint Plot gives Better idea about distribution and relation than
